# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
# Set default catalog and schema
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
# Aseguramos que exista el schema antes de usarlo
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog}.{schema}")
spark.sql(f"USE SCHEMA {schema}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Set default catalog and schema
# ----> 2 catalog = dbutils.widgets.get("catalog")
#       3 schema = dbutils.widgets.get("schema")
#       4 spark.sql(f"USE CATALOG {catalog}")
#
# NameError: name 'dbutils' is not defined

# %%
import os
import sys


obtener_ruta = os.getcwd()
print(obtener_ruta)

ruta_proyecto = os.path.abspath(os.path.join(obtener_ruta, ".."))
print(ruta_proyecto)

sys.path.append(ruta_proyecto)


# sys.path.append("../src")
# from dab_project import taxis

# taxis.find_all_taxis().show(10)
# Out:
# c:\Users\alexi\Desktop\0.Proyectos_DS\PROYECTYOS_DAB\dab_project\src
# c:\Users\alexi\Desktop\0.Proyectos_DS\PROYECTYOS_DAB\dab_project

# %%
# Obtener los parámetros que llegan como widgets
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")

# # Usarlos
# spark.sql(f"USE CATALOG {catalog}")
# spark.sql(f"CREATE SCHEMA IF NOT EXISTS {catalog}.{schema}")
# spark.sql(f"USE SCHEMA {catalog}.{schema}")
# Out:
# c:\Users\alexi\Desktop\0.Proyectos_DS\PROYECTYOS_DAB\dab_project\.venv\Lib\site-packages\databricks\sdk\_widgets\__init__.py:71: UserWarning:
# To use databricks widgets interactively in your notebook, please install databricks sdk using:
# 	pip install 'databricks-sdk[notebook]'
# Falling back to default_value_only implementation for databricks widgets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Obtener los parámetros que llegan como widgets
# ----> 2 catalog = dbutils.widgets.get("catalog")
#       3 schema = dbutils.widgets.get("schema")
#       5 # Usarlos
#
# File c:\Users\alexi\Desktop\0.Proyectos_DS\PROYECTYOS_DAB\dab_project\.venv\Lib\site-packages\databricks\sdk\_widgets\__init__.py:10, in WidgetUtils.get(self, name)
#       9 def get(self, name: str):
# ---> 10     return self._get(name)
#
# ...
